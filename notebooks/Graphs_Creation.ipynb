# %% [markdown]
# #Graphs Creation:

# %% [markdown]
# By: Itay Dar, Peleg Gitnik

# %%
import matplotlib.pyplot as plt

# %%
# Our Models Scores:
# Shape of model: [MAP@40 score, Mean retrieval time]
model1 = [0.251, 5.411]
model2 = [0.231, 8.436]
model3 = [0.347, 1.092]
model4 = [0.491, 0.721]
model5 = [0.555, 0.73]
# model5 = 
# model6 = 
# model7 = 

x_points = ["1st", "2nd", "3rd", "4th", "5th"]

# %%
# By score (g):
y_points1 = [model1[1], model2[1], model3[1], model4[1], model5[1]]

plt.plot(x_points, y_points1, "r")
plt.title("Search Engine graph - Average Retrieval Time per Version")
plt.xlabel("Search Engine Version")
plt.ylabel("Average Retrieval Time (sec)")
plt.show()

# %%
# By time (h):
y_points2 = [model1[0], model2[0], model3[0], model4[0], model5[0]]

plt.plot(x_points, y_points2)
plt.title("Search Engine graph - Scores")
plt.xlabel("Search Engine Version")
plt.ylabel("MAP@40 Score")
plt.show()
